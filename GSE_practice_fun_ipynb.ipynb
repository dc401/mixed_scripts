# %% [markdown]
# <a href="https://colab.research.google.com/github/dc401/mixed_scripts/blob/master/GSE_practice_fun_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **GSE Entrance/Labs Prep and Practice Fun**
#
# *Find more articles, tutorials, and tips on my Github and Medium Pages*
# * [https://github.com/dc401](https://github.com/dc401)
# * [https://medium.com/@dw.chow](https://medium.com/@dw.chow)

# %% [markdown]
# ***Scapy Setup***

# %%
pip install scapy
# Out:
# ...
#      |████████████████████████████████| 911kB 5.3MB/s
# ...
#   Created wheel for scapy: filename=scapy-2.4.3-py2.py3-none-any.whl size=1043873 sha256=c19ce148e5429fa3d13aca618444ec94d60040fd2f34f5f6d6ed0d7db7a53ffd
#   Stored in directory: /root/.cache/pip/wheels/95/bf/51/905b3e84ec4ca910ce4ae92173c7334623105a265bdd1d9438
# Successfully built scapy
# ...

# %%
#!/usr/bin/python
from scapy.all import *
import random
import sys, os

# %% [markdown]
# **Nmap Setup and Practice**

# %%
# !apt-get install nmap
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   liblinear3 liblua5.3-0 libpcap0.8
# Suggested packages:
#   liblinear-tools liblinear-dev ndiff
# The following NEW packages will be installed:
#   liblinear3 liblua5.3-0 libpcap0.8 nmap
# 0 upgraded, 4 newly installed, 0 to remove and 33 not upgraded.
# Need to get 5,446 kB of archives.
# After this operation, 24.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpcap0.8 amd64 1.8.1-6ubuntu1.18.04.1 [118 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblinear3 amd64 2.1.0+dfsg-2 [39.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblua5.3-0 amd64 5.3.3-1ubuntu0.18.04.1 [115 kB]
# ...

# %%
# !nmap -Pn -p 53 -n -v --open 8.8.8.8
# Out:
# Starting Nmap 7.60 ( https://nmap.org ) at 2020-07-13 02:55 UTC
# Initiating SYN Stealth Scan at 02:55
# Scanning 8.8.8.8 [1 port]
# Discovered open port 53/tcp on 8.8.8.8
# Completed SYN Stealth Scan at 02:55, 0.21s elapsed (1 total ports)
# Nmap scan report for 8.8.8.8
# Host is up (0.0011s latency).
#
# PORT   STATE SERVICE
# 53/tcp open  domain
#
# Read data files from: /usr/bin/../share/nmap
# Nmap done: 1 IP address (1 host up) scanned in 0.27 seconds
#            Raw packets sent: 1 (44B) | Rcvd: 1 (44B)

# %%
# !nmap -Pn -p 80,443 -sV xtecresearch.cloud --open
# Out:
# Starting Nmap 7.60 ( https://nmap.org ) at 2020-07-13 02:56 UTC
# Nmap scan report for xtecresearch.cloud (184.168.131.241)
# Host is up (0.037s latency).
# rDNS record for 184.168.131.241: ip-184-168-131-241.ip.secureserver.net
#
# PORT    STATE SERVICE  VERSION
# 80/tcp  open  http     nginx 1.16.1
# 443/tcp open  ssl/http nginx 1.16.1
#
# Service detection performed. Please report any incorrect results at https://nmap.org/submit/ .
# Nmap done: 1 IP address (1 host up) scanned in 13.46 seconds

# %% [markdown]
# **Tshark Practice**

# %%
# !apt-get install tshark
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libc-ares2 libcap2-bin liblua5.2-0 libmaxminddb0 libnl-genl-3-200 libpam-cap
#   libsbc1 libsmi2ldbl libspandsp2 libwireshark-data libwireshark11 libwiretap8
#   libwscodecs2 libwsutil9 wireshark-common
# Suggested packages:
#   mmdb-bin snmp-mibs-downloader wireshark-doc
# The following NEW packages will be installed:
#   libc-ares2 libcap2-bin liblua5.2-0 libmaxminddb0 libnl-genl-3-200 libpam-cap
#   libsbc1 libsmi2ldbl libspandsp2 libwireshark-data libwireshark11 libwiretap8
#   libwscodecs2 libwsutil9 tshark wireshark-common
# 0 upgraded, 16 newly installed, 0 to remove and 33 not upgraded.
# Need to get 16.4 MB of archives.
# ...

# %% [markdown]
# **Upload Session Pcaps and Examine. This will be cleared you will need to download your own from Wireshark's page via wget https://wiki.wireshark.org/SampleCaptures**

# %%
# !ls -lah; pwd; file ./UFTP_v5_transfer.pcapng
# Out:
# total 252K
# drwxr-xr-x 1 root root 4.0K Jul 13 03:07 .
# drwxr-xr-x 1 root root 4.0K Jul 13 02:41 ..
# drwxr-xr-x 1 root root 4.0K Jun 26 16:26 .config
# drwxr-xr-x 2 root root 4.0K Jul 13 03:03 .ipynb_checkpoints
# -rw-r--r-- 1 root root  43K Jul 13 03:04 maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap
# drwxr-xr-x 2 root root 4.0K Jul 13 03:03 pcaps
# drwxr-xr-x 1 root root 4.0K Jun 26 16:26 sample_data
# -rw-r--r-- 1 root root 181K Jul 13 03:07 UFTP_v5_transfer.pcapng
# /content
# ./UFTP_v5_transfer.pcapng: pcap-ng capture file - version 1.0

# %% [markdown]
# **Load the pcap into your scapy env. Remember the colab notebook sets up Python runtime env for you; we imported and installed Scapy earlier**

# %%
packets = rdpcap("UFTP_v5_transfer.pcapng")
packets[0].show()
# Out:
# ###[ Ethernet ]###
#   dst       = 01:00:5e:04:04:01
#   src       = 00:0c:29:e4:53:3b
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x2
#      len       = 68
#      id        = 36486
#      flags     =
#      frag      = 0
#      ttl       = 1
#      proto     = 17
#      chksum    = 0x7eb9
#      src       = 192.168.1.186
#      dst       = 230.4.4.1
#      \options   \
# ###[ UDP ]###
#         sport     = 48545
#         dport     = 1044
#         len       = 48
#         chksum    = 0xaa64
# ###[ Raw ]###
#            load      = 'P\x01\x00\x00\xc0\xa8\x01\xba\xe8\xd6\x10\xcb\x00\x9d\x00\x00\x01\x06\x00\x14\x02\x00\x05\x14\x00\x05\xa3\xf6\xb7\x17\xa1y\xe6\x04\x04\x01\xe6\x05\x05\xa2'

# %%
# !echo "$SHELL"; pwd; ls -lah
# Out:
# /bin/bash
# /content
# total 252K
# drwxr-xr-x 1 root root 4.0K Jul 13 03:07 .
# drwxr-xr-x 1 root root 4.0K Jul 13 02:41 ..
# drwxr-xr-x 1 root root 4.0K Jun 26 16:26 .config
# drwxr-xr-x 2 root root 4.0K Jul 13 03:03 .ipynb_checkpoints
# -rw-r--r-- 1 root root  43K Jul 13 03:04 maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap
# drwxr-xr-x 2 root root 4.0K Jul 13 03:03 pcaps
# drwxr-xr-x 1 root root 4.0K Jun 26 16:26 sample_data
# -rw-r--r-- 1 root root 181K Jul 13 03:07 UFTP_v5_transfer.pcapng

# %%
# !mkdir pcaps/output

# %%
# !tcpxtract --help
# Out:
# Usage: tcpxtract [OPTIONS] [[-d <DEVICE>] [-f <FILE>]]
# Valid options include:
#   --file, -f <FILE>         to specify an input capture file instead of a device
#   --device, -d <DEVICE>     to specify an input device (i.e. eth0)
#   --config, -c <FILE>       use FILE as the config file
#   --output, -o <DIRECTORY>  dump files to DIRECTORY instead of current directory
#   --version, -v             display the version number of this program
#   --help, -h                display this lovely screen

# %% [markdown]
# **tcpxtract syntax practice**

# %%
# !tcpxtract -f ./UFTP_v5_transfer.pcapng -o /content/pcaps/output
# Out:
# Found file of type "bmp" in session [192.168.1.201:5124 -> 192.168.1.186:41405], exporting to /content/pcaps/output/00000000.bmp
# Found file of type "bmp" in session [192.168.1.201:5124 -> 192.168.1.186:41405], exporting to /content/pcaps/output/00000001.bmp

# %%
# !file /content/pcaps/output/00000000.bmp; cat /content/pcaps/output/00000000.bmp | head -n 3
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-50-11553ae55ce9> in <module>()
# ----> 1 get_ipython().system('file /content/pcaps/output/00000000.bmp; cat /content/pcaps/output/00000000.bmp | head -n 3')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     439   shell.user_ns['_exit_code'] = result.returncode
# ...

# %%
# !testvar=$(tcpxtract -h); echo $testvar
# Out:
# Usage: tcpxtract [OPTIONS] [[-d <DEVICE>] [-f <FILE>]] Valid options include: --file, -f <FILE> to specify an input capture file instead of a device --device, -d <DEVICE> to specify an input device (i.e. eth0) --config, -c <FILE> use FILE as the config file --output, -o <DIRECTORY> dump files to DIRECTORY instead of current directory --version, -v display the version number of this program --help, -h display this lovely screen

# %% [markdown]
# **cat standard out does not return in the code snippet pane so you will need to redirect and view file in the browser. Click the folder icon to your left and browse**

# %%
# !cat /content/UFTP_v5_transfer.pcapng >> /content/pcaps/output/UFTP-stdout-.txt

# %%
# !apt-get install tcpdump ifconfig
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package ifconfig

# %%
# !tcpdump -v -i eth0 -Xs0 -c 2
# Out:
# tcpdump: listening on eth0, link-type EN10MB (Ethernet), capture size 262144 bytes
# 03:59:10.455811 IP (tos 0x0, ttl 64, id 11890, offset 0, flags [DF], proto TCP (6), length 726)
#     6185c36e9d40.9000 > kernel_manager_proxy_container.br0.43042: Flags [P.], cksum 0x5b06 (incorrect -> 0xb814), seq 663265451:663266125, ack 1653809688, win 6150, options [nop,nop,TS val 3509320727 ecr 755773504], length 674
# 	0x0000:  4500 02d6 2e72 4000 4006 b172 ac1c 0002  E....r@.@..r....
# 	0x0010:  ac1c 0003 2328 a822 2788 a0ab 6293 2218  ....#(."'...b.".
# 	0x0020:  8018 1806 5b06 0000 0101 080a d12b fc17  ....[........+..
# 	0x0030:  2d0c 3040 817e 029e 7b22 7061 7265 6e74  -.0@.~..{"parent
# 	0x0040:  5f68 6561 6465 7222 3a20 7b22 7573 6572  _header":.{"user
# 	0x0050:  6e61 6d65 223a 2022 7573 6572 6e61 6d65  name":."username
# 	0x0060:  222c 2022 7665 7273 696f 6e22 3a20 2235  ",."version":."5
# 	0x0070:  2e30 222c 2022 6d73 675f 7479 7065 223a  .0",."msg_type":
# ...

# %%
# !whoami; uname -a; cat /proc/version; sudo bash
# Out:
# root
# Linux 6185c36e9d40 4.19.104+ #1 SMP Wed Feb 19 05:26:34 PST 2020 x86_64 x86_64 x86_64 GNU/Linux
# Linux version 4.19.104+ (chrome-bot@chromeos-ci-legacy-us-central1-b-x32-96-hq3l) (Chromium OS 9.0_pre361749_p20190714-r4 clang version 9.0.0 (/var/cache/chromeos-cache/distfiles/host/egit-src/llvm-project c11de5eada2decd0a495ea02676b6f4838cd54fb) (based on LLVM 9.0.0svn)) #1 SMP Wed Feb 19 05:26:34 PST 2020
# bash: cannot set terminal process group (125): Inappropriate ioctl for device
# bash: no job control in this shell
# root@6185c36e9d40:/content# exit
# exit

# %%
# !tcpxtract -f ./maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap -o /content/pcaps/output/
# Out:
# Found file of type "bmp" in session [192.168.100.214:35328 -> 192.168.100.255:35328], exporting to /content/pcaps/output/00000000.bmp
# Found file of type "bmp" in session [192.168.100.214:35328 -> 192.168.100.255:35328], exporting to /content/pcaps/output/00000001.bmp
# Found file of type "html" in session [192.168.100.214:4032 -> 91.218.114.4:20480], exporting to /content/pcaps/output/00000002.html
# Found file of type "html" in session [91.218.114.4:20480 -> 192.168.100.214:4032], exporting to /content/pcaps/output/00000003.html
# Found file of type "html" in session [91.218.114.4:20480 -> 192.168.100.214:4032], exporting to /content/pcaps/output/00000004.html
# Found file of type "html" in session [91.218.114.4:20480 -> 192.168.100.214:4032], exporting to /content/pcaps/output/00000005.html
# Found file of type "html" in session [91.218.114.4:20480 -> 192.168.100.214:4032], exporting to /content/pcaps/output/00000006.html
# ...

# %%
# !capinfos /content/maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap
# Out:
# File name:           /content/maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap
# File type:           Wireshark/tcpdump/... - pcap
# File encapsulation:  Ethernet
# File timestamp precision:  microseconds (6)
# Packet size limit:   file hdr: 262144 bytes
# Number of packets:   297
# File size:           43 kB
# Data size:           38 kB
# Capture duration:    60.559973 seconds
# First packet time:   2020-07-08 21:51:32.931906
# Last packet time:    2020-07-08 21:52:33.491879
# Data byte rate:      639 bytes/s
# Data bit rate:       5,117 bits/s
# Average packet size: 130.44 bytes
# Average packet rate: 4 packets/s
# SHA256:              6c5706bbbfdedba3134b23cbb17e88a238236852a41f77e7c7b2c9f47aa1b240
# RIPEMD160:           d140fb4d9b9c3919f43a5823d924e6d2752cfabc
# SHA1:                790b6bbf31077854d84db1d79874a257bc1b9143
# Strict time order:   True
# Number of interfaces in file: 1
# Interface #0 info:
#                      Encapsulation = Ethernet (1 - ether)
# ...

# %%
packets = rdpcap("https://wiki.wireshark.org/SampleCaptures?action=AttachFile&do=get&target=kpasswd_tcp.cap")
packets[0].show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/scapy/utils.py in open(filename)
#     905             try:
# --> 906                 fdesc = gzip.open(filename, "rb")
#     907                 magic = fdesc.read(4)
#
# /usr/lib/python3.6/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# /usr/lib/python3.6/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# ...

# %% [markdown]
# **I guess scapy can't read direct from a url stream.. need to download it Python style using reqests**

# %%
import requests #use because downloads in binary format
url = "https://wiki.wireshark.org/SampleCaptures?action=AttachFile&do=get&target=kpasswd_tcp.cap"
readurl = requests.get(url) #create the object to grab the file
with open("/content/pcaps/kpasswd_tcp.pcap", "wb") as file: #open a file handler
  file.write(readurl.content) #perform write operation
# !ls /content/pcaps/*.pcap #bash list it in the directory
# Out:
# /content/pcaps/kpasswd_tcp.pcap

# %%
packets = rdpcap("/content/pcaps/kpasswd_tcp.pcap")
packets[11].summary()
packets[11].show()
# Out:
# ###[ Ethernet ]###
#   dst       = 00:01:30:10:a1:00
#   src       = 00:30:17:00:23:64
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 713
#      id        = 56514
#      flags     =
#      frag      = 0
#      ttl       = 128
#      proto     = 6
#      chksum    = 0x0
#      src       = 192.168.43.232
#      dst       = 10.2.20.154
#      \options   \
# ###[ TCP ]###
#         sport     = 1047
#         dport     = 464
#         seq       = 1308380550
#         ack       = 1782935238
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 64240
#         chksum    = 0x0
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
# ...

# %%
# !apt-get install dig host
# !dig myip.opendns.com @resolver1.opendns.com
# !host myip.opendns.com resovler1.opendns.com
# !curl ifconfig.me
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'bind9-host' instead of 'host'
# E: Unable to locate package dig
# /bin/bash: dig: command not found
# /bin/bash: host: command not found
# 35.185.214.90

# %% [markdown]
# **Various ways of grabbing your WAN IP address and modify existing packets in array in Scapy**

# %%
# !wget ipchicken.com
# !curl ifconfig.me
# Out:
# --2020-07-17 05:43:47--  http://ipchicken.com/
# Resolving ipchicken.com (ipchicken.com)... 104.26.8.109, 172.67.73.20, 104.26.9.109
# Connecting to ipchicken.com (ipchicken.com)|104.26.8.109|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ipchicken.com/ [following]
# --2020-07-17 05:43:47--  https://ipchicken.com/
# Connecting to ipchicken.com (ipchicken.com)|104.26.8.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [ <=>                ]   5.42K  --.-KB/s    in 0s
#
# 2020-07-17 05:43:47 (45.0 MB/s) - ‘index.html’ saved [5546]

# %%
packets[11].summary() #<-- prior packet 12 read from kerberos pcap read
# Out:
# 'Ether / IP / TCP 192.168.43.232:1047 > 10.2.20.154:464 PA / Raw'

# %%
#alter original packet from the pcap read in the array of packet 12
pktsend = packets[11] #<--copy original packet
pktsend[IP].src = "35.185.214.90"
pktsend[IP].dst = "portquiz.net"
pktsend.summary()
# Out:
# "Ether / IP / TCP 35.185.214.90:1047 > Net('portquiz.net'):464 PA / Raw"

# %%
#send packet without waiting on answer
send(pktsend)
# Out:
# Sent 1 packets.

# %%
#create new packet to confirmr esponse
pktsend = IP(dst="8.8.8.8")/TCP(dport=53, flags="S")/Raw(load="chow foo")
pktsend.show()
# Out:
# ###[ IP ]###
#   version   = 4
#   ihl       = None
#   tos       = 0x0
#   len       = None
#   id        = 1
#   flags     =
#   frag      = 0
#   ttl       = 64
#   proto     = 6
#   chksum    = None
#   src       = 172.28.0.2
#   dst       = 8.8.8.8
#   \options   \
# ###[ TCP ]###
#      sport     = 20
#      dport     = 53
#      seq       = 0
#      ack       = 0
#      dataofs   = None
#      reserved  = 0
#      flags     = S
#      window    = 8192
#      chksum    = None
#      urgptr    = 0
#      options   = []
# ###[ Raw ]###
#         load      = 'chow foo'

# %%
sr1(pktsend) #send and receive packet first response
# Out:
# Begin emission:
# Finished sending 1 packets.
#
# Received 1 packets, got 1 answers, remaining 0 packets
# <IP  version=4 ihl=5 tos=0x0 len=44 id=51333 flags= frag=0 ttl=114 proto=6 chksum=0xc418 src=8.8.8.8 dst=172.28.0.2 |<TCP  sport=53 dport=20 seq=1494014149 ack=1 dataofs=6 reserved=0 flags=SA window=65535 chksum=0xa9ea urgptr=0 options=[('MSS', 1430)] |>>

# %%
pktresp = sr1(pktsend)
pktresp.show()
# Out:
# Begin emission:
# Finished sending 1 packets.
#
# Received 1 packets, got 1 answers, remaining 0 packets
# ###[ IP ]###
#   version   = 4
#   ihl       = 5
#   tos       = 0x0
#   len       = 44
#   id        = 12424
#   flags     =
#   frag      = 0
#   ttl       = 114
#   proto     = 6
#   chksum    = 0x5c16
#   src       = 8.8.8.8
#   dst       = 172.28.0.2
#   \options   \
# ###[ TCP ]###
#      sport     = 53
#      dport     = 20
#      seq       = 3577110632
#      ack       = 1
#      dataofs   = 6
#      reserved  = 0
#      flags     = SA
#      window    = 65535
#      chksum    = 0xa61d
#      urgptr    = 0
#      options   = [('MSS', 1430)]

# %%
# !apt-get install zeek
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package zeek

# %%
# !tshark -r /content/maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap -z dns,tree
# Out:
# Running as user "root" and group "root". This could be dangerous.
#     1   0.000000 fe80::a179:b3ff:199:2314 → ff02::1:3    LLMNR 86 Standard query 0x9e8b A isatap
#     2   0.000116 192.168.100.214 → 224.0.0.252  LLMNR 66 Standard query 0x9e8b A isatap
#     3   0.001127 RealtekU_4a:04:af → Broadcast    ARP 42 Who has 192.168.100.2? Tell 192.168.100.214
#     4   0.001197 RealtekU_36:3e:ff → RealtekU_4a:04:af ARP 42 192.168.100.2 is at 52:54:00:36:3e:ff
#     5   0.038993 RealtekU_36:3e:ff → Broadcast    ARP 42 Who has 192.168.100.210? Tell 192.168.100.2
#     6   0.108826 fe80::a179:b3ff:199:2314 → ff02::1:3    LLMNR 86 Standard query 0x9e8b A isatap
#     7   0.108874 192.168.100.214 → 224.0.0.252  LLMNR 66 Standard query 0x9e8b A isatap
#     8   0.202590 192.168.100.214 → 192.168.100.255 NBNS 110 Registration NB WORKGROUP<1e>
#     9   0.312334 192.168.100.214 → 192.168.100.255 NBNS 92 Name query NB ISATAP<00>
# ...

# %%
# !tshark -r /content/maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap -z endpoints,ip -q
# Out:
# Running as user "root" and group "root". This could be dangerous.
# ...
# IPv4 Endpoints
# Filter:<No Filter>
#                        |  Packets  | |  Bytes  | | Tx Packets | | Tx Bytes | | Rx Packets | | Rx Bytes |
# 192.168.100.214              231         35075        151           20935          80           14140
# 192.168.100.255               45          6595          0               0          45            6595
# 91.218.114.4                  18          2787          8            1414          10            1373
# 91.218.114.11                 18          2795          8            1414          10            1381
# 91.218.114.25                 18          2806          8            1414          10            1392
# 91.218.114.26                 18          2776          8            1414          10            1362
# 91.218.114.31                 18          2824          8            1414          10            1410
# ...

# %%
# !tshark -r /content/maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap -Y "(ip.geoip.country == "United States")"
# Out:
# Running as user "root" and group "root". This could be dangerous.
# tshark: Display filters were specified both with "-Y" and with additional command-line arguments.

# %%
# !tshark -r /content/maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap -Y "!(tcp.port==443) && !(tcp.port==80)"
# Out:
# Running as user "root" and group "root". This could be dangerous.
#     1   0.000000 fe80::a179:b3ff:199:2314 → ff02::1:3    LLMNR 86 Standard query 0x9e8b A isatap
#     2   0.000116 192.168.100.214 → 224.0.0.252  LLMNR 66 Standard query 0x9e8b A isatap
#     3   0.001127 RealtekU_4a:04:af → Broadcast    ARP 42 Who has 192.168.100.2? Tell 192.168.100.214
#     4   0.001197 RealtekU_36:3e:ff → RealtekU_4a:04:af ARP 42 192.168.100.2 is at 52:54:00:36:3e:ff
#     5   0.038993 RealtekU_36:3e:ff → Broadcast    ARP 42 Who has 192.168.100.210? Tell 192.168.100.2
#     6   0.108826 fe80::a179:b3ff:199:2314 → ff02::1:3    LLMNR 86 Standard query 0x9e8b A isatap
#     7   0.108874 192.168.100.214 → 224.0.0.252  LLMNR 66 Standard query 0x9e8b A isatap
#     8   0.202590 192.168.100.214 → 192.168.100.255 NBNS 110 Registration NB WORKGROUP<1e>
#     9   0.312334 192.168.100.214 → 192.168.100.255 NBNS 92 Name query NB ISATAP<00>
# ...

# %%
# !tshark -r /content/maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap -Y "tcp contains "POST""
# Out:
# Running as user "root" and group "root". This could be dangerous.
#    21   2.438269 192.168.100.214 → 91.218.114.4 HTTP 586 POST /login/analytics/ook.shtml?kted=sds0ci HTTP/1.1  (application/x-www-form-urlencoded)
#    30   2.444971 192.168.100.214 → 91.218.114.11 HTTP 593 POST /yrlh.jspx?kce=2u6rk5f7&ujgn=7os2fm3705&br=s HTTP/1.1  (application/x-www-form-urlencoded)
#    39   2.452268 192.168.100.214 → 91.218.114.25 HTTP 593 POST /yrlh.jspx?kce=2u6rk5f7&ujgn=7os2fm3705&br=s HTTP/1.1  (application/x-www-form-urlencoded)
#    49   2.466447 192.168.100.214 → 91.218.114.26 HTTP 573 POST /lkn.shtml?et=7&d=2p86qb HTTP/1.1  (application/x-www-form-urlencoded)
#    58   2.478860 192.168.100.214 → 91.218.114.31 HTTP 600 POST /wire/a.php?bkaq=x3khe&ud=7f5&rcu=gv6u72o&g=vk162uf HTTP/1.1  (application/x-www-form-urlencoded)
#    67   2.494429 192.168.100.214 → 91.218.114.32 HTTP 600 POST /wire/a.php?bkaq=x3khe&ud=7f5&rcu=gv6u72o&g=vk162uf HTTP/1.1  (application/x-www-form-urlencoded)
# ...

# %% [markdown]
# **Tshark syntax normal in bash green. But in Colab's Python CLI interpreter you need to set the regex as a string variable first and then call it in the next line**

# %%
#!tshark -r /content/maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap -Y 'http && http.request.uri matches ".{1,10}"' <-- syntax parsing issue
# !regexstr=".{1,10}"
# !tshark -r /content/maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap -Y "http.request.uri $regexstr"
# Out:
# Running as user "root" and group "root". This could be dangerous.
#    21   2.438269 192.168.100.214 → 91.218.114.4 HTTP 586 POST /login/analytics/ook.shtml?kted=sds0ci HTTP/1.1  (application/x-www-form-urlencoded)
#    30   2.444971 192.168.100.214 → 91.218.114.11 HTTP 593 POST /yrlh.jspx?kce=2u6rk5f7&ujgn=7os2fm3705&br=s HTTP/1.1  (application/x-www-form-urlencoded)
#    39   2.452268 192.168.100.214 → 91.218.114.25 HTTP 593 POST /yrlh.jspx?kce=2u6rk5f7&ujgn=7os2fm3705&br=s HTTP/1.1  (application/x-www-form-urlencoded)
#    49   2.466447 192.168.100.214 → 91.218.114.26 HTTP 573 POST /lkn.shtml?et=7&d=2p86qb HTTP/1.1  (application/x-www-form-urlencoded)
#    58   2.478860 192.168.100.214 → 91.218.114.31 HTTP 600 POST /wire/a.php?bkaq=x3khe&ud=7f5&rcu=gv6u72o&g=vk162uf HTTP/1.1  (application/x-www-form-urlencoded)
#    67   2.494429 192.168.100.214 → 91.218.114.32 HTTP 600 POST /wire/a.php?bkaq=x3khe&ud=7f5&rcu=gv6u72o&g=vk162uf HTTP/1.1  (application/x-www-form-urlencoded)
# ...

# %%
# !tshark -r /content/maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap -z conv,tcp -z conv,udp -q
# Out:
# Running as user "root" and group "root". This could be dangerous.
# ...
# UDP Conversations
# Filter:<No Filter>
#                                                            |       <-      | |       ->      | |     Total     |    Relative    |   Duration   |
#                                                            | Frames  Bytes | | Frames  Bytes | | Frames  Bytes |      Start     |              |
# 192.168.100.214:137        <-> 192.168.100.255:137              0         0      28      2738      28      2738     0.202590000        24.0471
# 192.168.100.214:138        <-> 192.168.100.255:138              0         0      17      3857      17      3857     0.953135000        26.2288
# ff02::1:2:547              <-> fe80::a179:b3ff:199:2314:546       3       447       0         0       3       447     6.999528000        47.9999
# fe80::a179:b3ff:199:2314:51469 <-> ff02::1:3:5355                   0         0       2       172       2       172     0.000000000         0.1088
# ...

# %% [markdown]
# **Silk and Yaf Installation Agony and Flow Analysis**

# %%
#dependencies for yaf and silk https://isc.sans.edu/forums/diary/Netflow+on+Nexus+1000v/16865/
# !sudo apt-get -y install libglib2.0-dev
# !sudo apt-get -y install libpcap-dev
# !sudo apt-get -y install python-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libglib2.0-dev is already the newest version (2.56.4-0ubuntu0.18.04.6).
# libglib2.0-dev set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   libpcap0.8-dev
# The following NEW packages will be installed:
#   libpcap-dev libpcap0.8-dev
# 0 upgraded, 2 newly installed, 0 to remove and 33 not upgraded.
# Need to get 222 kB of archives.
# After this operation, 749 kB of additional disk space will be used.
# ...

# %%
# !wget https://tools.netsa.cert.org/releases/silk-3.19.1.tar.gz
# !wget https://tools.netsa.cert.org/releases/yaf-2.11.0.tar.gz
# !wget https://tools.netsa.cert.org/releases/libfixbuf-2.4.0.tar.gz
# Out:
# --2020-07-13 06:15:55--  https://tools.netsa.cert.org/releases/silk-3.19.1.tar.gz
# Resolving tools.netsa.cert.org (tools.netsa.cert.org)... 147.72.252.217
# Connecting to tools.netsa.cert.org (tools.netsa.cert.org)|147.72.252.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5605238 (5.3M) [application/x-gzip]
# Saving to: ‘silk-3.19.1.tar.gz’
#
# silk-3.19.1.tar.gz  100%[===================>]   5.34M  1007KB/s    in 5.7s
#
# 2020-07-13 06:16:02 (953 KB/s) - ‘silk-3.19.1.tar.gz’ saved [5605238/5605238]
#
# --2020-07-13 06:16:02--  https://tools.netsa.cert.org/releases/yaf-2.11.0.tar.gz
# Resolving tools.netsa.cert.org (tools.netsa.cert.org)... 147.72.252.217
# Connecting to tools.netsa.cert.org (tools.netsa.cert.org)|147.72.252.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2132776 (2.0M) [application/x-gzip]
# Saving to: ‘yaf-2.11.0.tar.gz’
#
# ...

# %%
# !tar -zxvf ./libfixbuf-2.4.0.tar.gz
# Out:
# libfixbuf-2.4.0/
# libfixbuf-2.4.0/libfixbuf.spec.in
# libfixbuf-2.4.0/configure.ac
# libfixbuf-2.4.0/INSTALL
# libfixbuf-2.4.0/configure
# libfixbuf-2.4.0/AUTHORS
# libfixbuf-2.4.0/include/
# libfixbuf-2.4.0/include/Makefile.am
# libfixbuf-2.4.0/include/fixbuf/
# libfixbuf-2.4.0/include/fixbuf/version.h.in
# libfixbuf-2.4.0/include/fixbuf/config.h.in
# libfixbuf-2.4.0/include/fixbuf/private.h
# libfixbuf-2.4.0/include/fixbuf/public.h
# libfixbuf-2.4.0/include/fixbuf/autoinc.h
# libfixbuf-2.4.0/include/Makefile.in
# libfixbuf-2.4.0/Doxyfile.in
# libfixbuf-2.4.0/README
# libfixbuf-2.4.0/Makefile.am
# libfixbuf-2.4.0/NEWS
# libfixbuf-2.4.0/doxygen.am
# libfixbuf-2.4.0/libfixbuf.pc.in
# libfixbuf-2.4.0/autoconf/
# libfixbuf-2.4.0/autoconf/install-sh
# libfixbuf-2.4.0/autoconf/ltmain.sh
# libfixbuf-2.4.0/autoconf/config.guess
# libfixbuf-2.4.0/autoconf/depcomp
# libfixbuf-2.4.0/autoconf/missing
# libfixbuf-2.4.0/autoconf/config.sub
# libfixbuf-2.4.0/autoconf/compile
# ...

# %%
# !cd /content/libfixbuf-2.4.0/; ls; ./configure; make; sudo make install
# Out:
# aclocal.m4  configure.ac  include	     LICENSE.txt  NEWS
# AUTHORS     doc		  INSTALL	     m4		  README
# autoconf    Doxyfile.in   libfixbuf.pc.in    Makefile.am  src
# configure   doxygen.am	  libfixbuf.spec.in  Makefile.in
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking how to print strings... printf
# checking whether make supports the include directive... yes (GNU style)
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# ...

# %%
# !tar -xvf ./yaf-2.11.0.tar.gz
# Out:
# yaf-2.11.0/
# yaf-2.11.0/scripts/
# yaf-2.11.0/scripts/yafMeta2Pcap.pod
# yaf-2.11.0/scripts/getFlowKeyHash.c
# yaf-2.11.0/scripts/yafzcbalance.pod
# yaf-2.11.0/scripts/getFlowKeyHash.pod
# yaf-2.11.0/scripts/Makefile.am
# yaf-2.11.0/scripts/yafMeta2Pcap.c
# yaf-2.11.0/scripts/yafzcbalance.c
# yaf-2.11.0/scripts/Makefile.in
# yaf-2.11.0/make-infomodel
# yaf-2.11.0/include/
# yaf-2.11.0/include/yaf/
# yaf-2.11.0/include/yaf/yafcore.h
# yaf-2.11.0/include/yaf/yaftab.h
# yaf-2.11.0/include/yaf/ring.h
# yaf-2.11.0/include/yaf/decode.h
# yaf-2.11.0/include/yaf/yafrag.h
# yaf-2.11.0/include/yaf/yafhooks.h
# yaf-2.11.0/include/yaf/picq.h
# yaf-2.11.0/include/yaf/autoinc.h
# yaf-2.11.0/include/yaf/config.h.in
# yaf-2.11.0/include/Makefile.am
# yaf-2.11.0/include/Makefile.in
# yaf-2.11.0/Doxyfile.in
# yaf-2.11.0/doc/
# yaf-2.11.0/doc/doxygen.css
# yaf-2.11.0/doc/Doxyfoot.html
# yaf-2.11.0/doc/howto/
# yaf-2.11.0/doc/howto/yaf_silk.md
# yaf-2.11.0/doc/howto/yaf_orcus.md
# ...

# %%
# !cd /content/yaf-2.11.0; ls; !PKG_CONFIG_PATH=/usr/local/lib/pkgconfig; ./configure; make; sudo make install
# Out:
# acinclude.m4  configure.ac	 etc	       m4	       README.in
# aclocal.m4    COPYING		 include       Makefile.am     scripts
# airframe      doc		 infomodel     Makefile.in     src
# AUTHORS       Doxyfile.in	 libltdl       make-infomodel  xml2fixbuf.xslt
# autoconf      doxygen.am	 libyaf.pc.in  NEWS	       yaf.spec
# configure     DoxygenLayout.xml  lua	       README	       yaf.spec.in
# /bin/bash: !PKG_CONFIG_PATH=/usr/local/lib/pkgconfig: No such file or directory
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking target system type... x86_64-pc-linux-gnu
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# ...

# %%
# !tar -xvzf ./silk-3.19.1.tar.gz
# Out:
# silk-3.19.1/
# silk-3.19.1/configure.ac
# silk-3.19.1/configure
# silk-3.19.1/lib-deps.mk
# silk-3.19.1/tests/
# silk-3.19.1/tests/fake-cc-v6.csv
# silk-3.19.1/tests/set1-v4.txt
# silk-3.19.1/tests/set1-v6.txt
# silk-3.19.1/tests/make-scandata.pl
# silk-3.19.1/tests/make-sendrcv-data.pl
# silk-3.19.1/tests/pysilk-plugin.py
# silk-3.19.1/tests/set3-v6.txt
# silk-3.19.1/tests/ip-map-v6.txt
# silk-3.19.1/tests/set3-v4.txt
# silk-3.19.1/tests/fake-cc.csv
# silk-3.19.1/tests/SiLKTests.pm
# silk-3.19.1/tests/config_vars.py.in
# silk-3.19.1/tests/bag2-v6.txt
# silk-3.19.1/tests/bag2-v4.txt
# silk-3.19.1/tests/ip-map.txt
# silk-3.19.1/tests/Makefile.am
# silk-3.19.1/tests/daemon_test.py
# silk-3.19.1/tests/set2-v4.txt
# silk-3.19.1/tests/set2-v6.txt
# silk-3.19.1/tests/bag1-v6.txt
# silk-3.19.1/tests/address_types.txt
# silk-3.19.1/tests/proto-port-map.txt
# silk-3.19.1/tests/bag1-v4.txt
# silk-3.19.1/tests/Makefile.in
# silk-3.19.1/tests/set4-v6.txt
# silk-3.19.1/tests/bag3-v4.txt
# ...

# %%
# !cd /content/silk-3.19.1; ls; ./configure \
 --with-libfixbuf=/usr/local/lib/pkgconfig/ \
 --with-python; make; sudo make install
# Out:
# aclocal.m4  configure	  lib-deps.mk  Makefile.am  silk.spec.in  tests
# autoconf    configure.ac  LICENSE.txt  Makefile.in  site
# build.mk    doc		  m4	       README.txt   src
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking whether to enable maintainer-specific portions of Makefiles... no
# checking whether make supports the include directive... yes (GNU style)
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# ...

# %%
# !touch /content/silk.conf; echo "/usr/local/lib" >> /content/silk.conf; echo "/usr/local/lib/silk" >> /content/silk.conf; echo "EOF" >> "/content/silk.conf"

# %%
# !sudo mv /content/silk.conf /etc/ld.so.conf.d/

# %%
# !ldconfig
# Out:
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
#convert pcaps to silk compatible ipfix flows
# !rwptoflow ./maze-bf21e76d-778e-4243-8c17-e7391a2cac98.pcap --flow-out=./maze-flows.rw
# Out:
# rwptoflow: Will not create new file over existing file './maze-flows.rw': File exists

# %%
# !rwstats ./maze-flows.rw --fields=protocol --count=5
# Out:
# INPUT: 231 Records for 2 Bins and 231 Total Records
# OUTPUT: Top 5 Bins by Records
# pro|   Records|  %Records|   cumul_%|
#   6|       180| 77.922078| 77.922078|
#  17|        51| 22.077922|100.000000|

# %%
# !rwcut ./maze-flows.rw --fields=sIP,dIP,sPort,dPort,protocol,bytes,flag,duration --num-recs=10
# Out:
#             sIP|            dIP|sPort|dPort|pro|     bytes|   flags| duration|
# 192.168.100.214|    224.0.0.252|52449| 5355| 17|        52|        |    0.000|
# 192.168.100.214|    224.0.0.252|52449| 5355| 17|        52|        |    0.000|
# 192.168.100.214|192.168.100.255|  137|  137| 17|        96|        |    0.000|
# 192.168.100.214|192.168.100.255|  137|  137| 17|        78|        |    0.000|
# 192.168.100.214|192.168.100.255|  137|  137| 17|        78|        |    0.000|
# 192.168.100.214|192.168.100.255|  138|  138| 17|       206|        |    0.000|
# 192.168.100.214|192.168.100.255|  138|  138| 17|       229|        |    0.000|
# 192.168.100.214|192.168.100.255|  137|  137| 17|        78|        |    0.000|
# 192.168.100.214|192.168.100.255|  137|  137| 17|        78|        |    0.000|
# 192.168.100.214|   91.218.114.4|49167|   80|  6|        52| S      |    0.000|

# %%
# !rwfilter ./maze-flows.rw --pass=stdout --end-date=2020/07/08 | rwcut -f1-8 #wont work in this env but useful syntax
# Out:
# rwfilter: Site configuration file not found
# rwcut: unrecognized option '-f1-8'
# Use 'rwcut --help' for usage

# %%
# !iptables -L
# Out:
# /bin/bash: iptables: command not found

# %%
# !apt-get install gnupg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gnupg is already the newest version (2.2.4-1ubuntu1.2).
# gnupg set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %% [markdown]
# **Let's install Zeek/Bro**

# %%
# !apt-get install cmake make gcc g++ flex bison libpcap-dev libssl-dev python-dev swig zlib1g-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# make is already the newest version (4.1-9.1ubuntu1).
# make set to manually installed.
# python-dev is already the newest version (2.7.15~rc1-1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# g++ is already the newest version (4:7.4.0-1ubuntu2.3).
# g++ set to manually installed.
# gcc is already the newest version (4:7.4.0-1ubuntu2.3).
# gcc set to manually installed.
# libssl-dev is already the newest version (1.1.1-1ubuntu2.1~18.04.6).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libbison-dev libfl-dev libfl2 libpcap0.8 libpcap0.8-dev libsigsegv2 m4
#   swig3.0
# Suggested packages:
# ...

# %%
# !git clone --recursive https://github.com/zeek/zeek
# Out:
# Cloning into 'zeek'...
# remote: Enumerating objects: 301, done.
# remote: Counting objects: 100% (301/301), done.
# remote: Compressing objects: 100% (277/277), done.
# remote: Total 144779 (delta 76), reused 61 (delta 24), pack-reused 144478
# Receiving objects: 100% (144779/144779), 91.43 MiB | 17.42 MiB/s, done.
# Resolving deltas: 100% (104430/104430), done.
# Submodule 'auxil/bifcl' (https://github.com/zeek/bifcl) registered for path 'auxil/bifcl'
# Submodule 'auxil/binpac' (https://github.com/zeek/binpac) registered for path 'auxil/binpac'
# Submodule 'auxil/broker' (https://github.com/zeek/broker) registered for path 'auxil/broker'
# Submodule 'auxil/btest' (https://github.com/zeek/btest) registered for path 'auxil/btest'
# Submodule 'auxil/highwayhash' (https://github.com/zeek/highwayhash) registered for path 'auxil/highwayhash'
# Submodule 'auxil/libkqueue' (https://github.com/zeek/libkqueue) registered for path 'auxil/libkqueue'
# ...

# %%
# !cd zeek; ls
# Out:
# auxil		configure	  Makefile   scripts	       zeek-config.in
# CHANGES		COPYING		  man	     src	       zeek-path-dev.in
# ci		COPYING.3rdparty  NEWS	     testing	       zeek-wrapper.in
# cmake		doc		  README     VERSION
# CMakeLists.txt	INSTALL		  README.md  zeek-config.h.in

# %% [markdown]
# **This part will take a LONG time. To prevent hitting the 90 minute timeout session stay in the console and move around baby sitting it until it's done compiling for you. This is a BASIC compile without enhanced libraries.**

# %%
# !cd zeek;./configure; make; make install
# Out:
# Streaming output truncated to the last 5000 lines.
# make[3]: Entering directory '/content/zeek/build'
# [ 50%] Building CXX object src/analyzer/protocol/gtpv1/CMakeFiles/plugin-Zeek-GTPv1.dir/GTPv1.cc.o
# [ 50%] Building CXX object src/analyzer/protocol/gtpv1/CMakeFiles/plugin-Zeek-GTPv1.dir/Plugin.cc.o
# [ 50%] Building CXX object src/analyzer/protocol/gtpv1/CMakeFiles/plugin-Zeek-GTPv1.dir/events.bif.cc.o
# [ 50%] Building CXX object src/analyzer/protocol/gtpv1/CMakeFiles/plugin-Zeek-GTPv1.dir/events.bif.init.cc.o
# [ 50%] Building CXX object src/analyzer/protocol/gtpv1/CMakeFiles/plugin-Zeek-GTPv1.dir/gtpv1_pac.cc.o
# make[3]: Leaving directory '/content/zeek/build'
# [ 50%] Built target plugin-Zeek-GTPv1
# make[3]: Entering directory '/content/zeek/build'
# Scanning dependencies of target plugin-Zeek-HTTP
# make[3]: Leaving directory '/content/zeek/build'
# make[3]: Entering directory '/content/zeek/build'
# ...

# %%
#find my shell 
# !echo $SHELL
#export path only for this codeblock session
#!export PATH=/usr/local/zeek/bin:$PATH
# !ls /usr/local/zeek/bin/
# !export PATH=/usr/local/zeek/bin:$PATH
# !pwd
#let's grab something from http://malware-traffic-analysis.net/training-exercises.html
# !wget http://malware-traffic-analysis.net/2020/06/12/2020-06-12-traffic-analysis-exercise.pcap.zip
# Out:
# /bin/bash
# bifcl	    broctl		      capstats	     zeek-config
# binpac	    bro-cut		      paraglob-test  zeekctl
# bro	    broker-benchmark	      trace-summary  zeek-cut
# bro-config  broker-cluster-benchmark  zeek	     zeek-wrapper
# /content
# --2020-07-17 05:48:45--  http://malware-traffic-analysis.net/2020/06/12/2020-06-12-traffic-analysis-exercise.pcap.zip
# Resolving malware-traffic-analysis.net (malware-traffic-analysis.net)... 166.78.135.34
# Connecting to malware-traffic-analysis.net (malware-traffic-analysis.net)|166.78.135.34|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5481011 (5.2M) [application/zip]
# Saving to: ‘2020-06-12-traffic-analysis-exercise.pcap.zip’
#
# 2020-06-12-traffic- 100%[===================>]   5.23M  4.01MB/s    in 1.3s
#
# 2020-07-17 05:48:47 (4.01 MB/s) - ‘2020-06-12-traffic-analysis-exercise.pcap.zip’ saved [5481011/5481011]

# %%
#http://malware-traffic-analysis.net/2020/06/12/index.html
# !unzip -P infected ./2020-06-12-traffic-analysis-exercise.pcap.zip
# Out:
# Archive:  ./2020-06-12-traffic-analysis-exercise.pcap.zip
#   inflating: 2020-06-12-traffic-analysis-exercise.pcap

# %% [markdown]
# **Have to do initial setup and config deploy of Zeek starting it up.**

# %%
# !/usr/local/zeek/bin/zeekctl deploy
# !/usr/local/zeek/bin/zeekctl start
# !/usr/local/zeek/bin/zeek ./2020-06-12-traffic-analysis-exercise.pcap
# Out:
# ...
# checking configurations ...
# installing ...
# removing old policies in /usr/local/zeek/spool/installed-scripts-do-not-touch/site ...
# removing old policies in /usr/local/zeek/spool/installed-scripts-do-not-touch/auto ...
# creating policy directories ...
# installing site policies ...
# generating standalone-layout.zeek ...
# generating local-networks.zeek ...
# generating zeekctl-config.zeek ...
# generating zeekctl-config.sh ...
# stopping ...
# stopping zeek ...
# starting ...
# starting zeek ...
# ...
# starting zeek ...
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-40-3940742e0e91> in <module>()
#       1 get_ipython().system('/usr/local/zeek/bin/zeekctl deploy')
#       2 get_ipython().system('/usr/local/zeek/bin/zeekctl start')
# ----> 3 get_ipython().system('/usr/local/zeek/bin/zeek ./2020-06-12-traffic-analysis-exercise.pcap')
#
# ...

# %% [markdown]
# **Well that shuts down our zeek fun-- no apt-get install for ifconfig and I'm not going to try to compile it. Use the Google Cloud Platform Free Tier F1 Micro instance for this**
# https://cloud.google.com/free

# %%
# !apt-get update
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Get:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:6 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# ...

# %% [markdown]
# **Never mind I just wasted a bunch of time and energy not updating apt cache and going for zeek vs. bro's package name d'oh.**

# %%
# !apt-get install bro
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   bro-common geoip-database libgeoip1
# Suggested packages:
#   geoip-bin
# The following NEW packages will be installed:
#   bro bro-common geoip-database libgeoip1
# 0 upgraded, 4 newly installed, 0 to remove and 66 not upgraded.
# Need to get 4,535 kB of archives.
# After this operation, 17.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 geoip-database all 20180315-1 [2,090 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgeoip1 amd64 1.6.12-1 [71.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 bro-common all 2.5.3-1build1 [571 kB]
# ...

# %%
# !bro 2020-06-12-traffic-analysis-exercise.pcap
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-47-4eba5cef6373> in <module>()
# ----> 1 get_ipython().system('bro 2020-06-12-traffic-analysis-exercise.pcap')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     439   shell.user_ns['_exit_code'] = result.returncode
#     440   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# ...

# %% [markdown]
# **Screw it... ipython doesn't seem to like it due to file names... let's try the variable method again like earlier, sigh...**

# %%
# !pcapname="2020-06-12-traffic-analysis-exercise.pcap"
# !bro $pcapname
